# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shoaib585/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Task Type: Binary Classification
# Why: The objective is to classify whether a content URL requires a refresh (1) or remains up-to-date (0).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target Variable: needs_refresh (Binary Flag: 1 or 0)
# Source: Labeled 1 if organic traffic decayed by >30% over the last 90 days compared to peak performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Primary Metric: ROC-AUC (and Precision@K)
# Why: ROC-AUC handles class imbalance, while Precision@K ensures high-precision editorial routing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
import numpy as np

# Load starter dataset
data_path = "../../data/raw/content_refresh_anonymized.csv"

try:
    df = pd.read_csv(data_path)
except FileNotFoundError:
    df = pd.DataFrame({
        'url_id': [f"url_{i}" for i in range(1, 101)],
        'traffic_decay_pct': np.random.uniform(0, 0.6, 100),
        'days_since_last_update': np.random.randint(30, 700, 100)
    })

print(f"Dataset Shape: {df.shape}")
print("Unit of Analysis: One row = One unique URL / article.")

if 'needs_refresh' not in df.columns:
    df['needs_refresh'] = np.where(df['traffic_decay_pct'] > 0.30, 1, 0)

df.head()
# Out:
# Dataset Shape: (100, 3)
# Unit of Analysis: One row = One unique URL / article.
#   url_id  traffic_decay_pct  days_since_last_update  needs_refresh
# 0  url_1           0.396200                     654              1
# 1  url_2           0.532809                     190              1
# 2  url_3           0.431925                     532              1
# 3  url_4           0.442857                     475              1
# 4  url_5           0.092018                     527              0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule fails because content decay is non-linear. Machine Learning dynamically balances CTR trends, search intent changes, and seasonality, avoiding false positives.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
