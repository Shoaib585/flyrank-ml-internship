# %% [markdown]
# <a href="https://colab.research.google.com/github/Shoaib585/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Shoaib585/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# !ls
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 124 (delta 38), reused 92 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.82 MiB | 6.67 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/flyrank-ml-internship/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import os
print(os.getcwd())
# !find . -name "*.csv"
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship
# ./outputs/refresh_queue_sample.csv
# ./data/raw/content_refresh_anonymized.csv

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shoaib585/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the **Content Refresh Prioritization** lane.
#
# I selected this lane because websites often contain hundreds or thousands of pages, making it difficult to decide which pages should be refreshed first. A data-driven approach can help identify pages that are more likely to benefit from updates, allowing the SEO team to focus on the highest-priority content.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question
#
# **Decision:** Which pages should be prioritized for content refresh?
#
# **Who acts on it?**
# The SEO or content team uses the recommendations to decide which pages should be reviewed and updated first.
#
# **Action:**
# Review, refresh, and optimize the highest-priority pages before their performance declines further.
#
# **Cost of a Wrong Recommendation:**
# If the wrong pages are recommended, the team may spend time updating pages that do not need attention while important pages continue losing traffic. This can reduce the efficiency of the content strategy.
#
# **Why Machine Learning Can Help:**
# Machine learning can identify patterns from historical search and content data that are difficult to capture with simple manual rules. The model supports decision-making but does not replace human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# I explored the starter dataset to understand whether the Content Refresh Prioritization lane is worth investigating. The statistics printed below provide an initial overview of the dataset and help support this research question.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Total columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30000
# Total columns: 44
# Average CTR: 0.511
# Average Position: 16.34
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project will identify patterns and relationships within the internship dataset to support content refresh decisions. Any findings will be observational and directional, helping prioritize pages that may benefit from updates.
#
# This project will **not** prove causation, explain or predict Google's ranking algorithms, or guarantee future search performance. The model is intended as a decision-support tool and should always be used alongside human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
